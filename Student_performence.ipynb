# %% [markdown]
# # **Student Performance**

# %% [markdown]
# ##**Data Preprocessing**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv('student-por.csv')
data.head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        4   0  11  11
# 1     GP   F   17       U     GT3       T  ...     1       3        2   9  11  11
# 2     GP   F   15       U     LE3       T  ...     3       3        6  12  13  12
# 3     GP   F   15       U     GT3       T  ...     1       5        0  14  14  14
# 4     GP   F   16       U     GT3       T  ...     2       5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
data.shape
# Out:
# (649, 33)

# %% [markdown]
# **Chack the unique and null velues**

# %%
print(data['famsize'].unique())
print(data['address'].unique())
print(data['Mjob'].unique())
print(data['Fjob'].unique())
print(data['guardian'].unique())
# Out:
# ['GT3' 'LE3']
# ['U' 'R']
# ['at_home' 'health' 'other' 'services' 'teacher']
# ['teacher' 'other' 'services' 'health' 'at_home']
# ['mother' 'father' 'other']

# %%
data.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data = data[['school','sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob',
       'Fjob', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup',
       'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet',
       'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health',
       'absences', 'G1', 'G2', 'G3']]

# %%
data.shape
# Out:
# (649, 32)

# %%
data.describe()
# Out:
#               age        Medu        Fedu  ...          G1          G2          G3
# count  649.000000  649.000000  649.000000  ...  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626  ...   11.399076   11.570108   11.906009
# std      1.218138    1.134552    1.099931  ...    2.745265    2.913639    3.230656
# min     15.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     16.000000    2.000000    1.000000  ...   10.000000   10.000000   10.000000
# 50%     17.000000    2.000000    2.000000  ...   11.000000   11.000000   12.000000
# 75%     18.000000    4.000000    3.000000  ...   13.000000   13.000000   14.000000
# max     22.000000    4.000000    4.000000  ...   19.000000   19.000000   19.000000
#
# [8 rows x 16 columns]

# %% [markdown]
# ##**Correletion Matrix & Heatmap**

# %%
data.corr()
# Out:
#                  age      Medu      Fedu  ...        G1        G2        G3
# age         1.000000 -0.107832 -0.121050  ... -0.174322 -0.107119 -0.106505
# Medu       -0.107832  1.000000  0.647477  ...  0.260472  0.264035  0.240151
# Fedu       -0.121050  0.647477  1.000000  ...  0.217501  0.225139  0.211800
# traveltime  0.034490 -0.265079 -0.208288  ... -0.154120 -0.154489 -0.127173
# studytime  -0.008415  0.097006  0.050400  ...  0.260875  0.240498  0.249789
# failures    0.319968 -0.172210 -0.165915  ... -0.384210 -0.385782 -0.393316
# famrel     -0.020559  0.024421  0.020256  ...  0.048795  0.089588  0.063361
# freetime   -0.004910 -0.019686  0.006841  ... -0.094497 -0.106678 -0.122705
# goout       0.112805  0.009536  0.027690  ... -0.074053 -0.079469 -0.087641
# Dalc        0.134768 -0.007018  0.000061  ... -0.195171 -0.189480 -0.204719
# Walc        0.086357 -0.019766  0.038445  ... -0.155649 -0.164852 -0.176619
# ...

# %%
sns.pairplot(data)

# %%
plt.subplots(figsize=(15,8))

sns.heatmap(data.corr(), annot=True, cmap="YlOrBr")

# %% [markdown]
# ##**Groupby Matrix**

# %%
data.groupby('sex').mean()
# Out:
#            age      Medu      Fedu  ...         G1         G2         G3
# sex                                 ...
# F    16.788512  2.402089  2.229765  ...  11.637076  11.822454  12.253264
# M    16.680451  2.676692  2.417293  ...  11.056391  11.206767  11.406015
#
# [2 rows x 16 columns]

# %%
data.groupby('address').mean()
# Out:
#                age      Medu      Fedu  ...         G1         G2         G3
# address                                 ...
# R        16.791878  2.187817  2.071066  ...  10.746193  10.888325  11.086294
# U        16.723451  2.657080  2.409292  ...  11.683628  11.867257  12.263274
#
# [2 rows x 16 columns]

# %%
data.groupby('school').mean()
# Out:
#               age      Medu      Fedu  ...         G1         G2         G3
# school                                 ...
# GP      16.666667  2.725768  2.475177  ...  11.985816  12.144208  12.576832
# MS      16.889381  2.119469  1.991150  ...  10.300885  10.495575  10.650442
#
# [2 rows x 16 columns]

# %% [markdown]
# ##**Variable reletion and visulizetion**

# %%
sns.countplot(x = 'G3', data = data )

# %%
sns.barplot(x='school', y='G3',data=data)

# %%
sns.barplot(x='sex', y='G3',data=data)

# %%
sns.barplot(x='guardian', y='G3',data=data)

# %%
sns.barplot(x='romantic', y='G3',data=data)

# %%
sns.barplot(x='Pstatus', y='G3',data=data)

# %%
sns.barplot(x='Medu', y='G3',data=data)

# %%
sns.barplot(x='Fedu', y='G3',data=data)

# %%
sns.barplot(x='Mjob', y='G3',data=data)

# %%
sns.barplot(x='Fjob', y='G3',data=data)

# %%
sns.barplot(x='traveltime', y='G3',data=data)

# %%
sns.barplot(x='famrel', y='G3',data=data)

# %%
sns.barplot(x='studytime', y='G3',data=data)

# %%
sns.barplot(x='failures', y='G3',data=data)

# %%
sns.barplot(x='schoolsup', y='G3',data=data)

# %%
sns.barplot(x='famsup', y='G3',data=data)

# %%
sns.barplot(x='paid', y='G3',data=data)

# %%
sns.barplot(x='activities', y='G3',data=data)

# %%
sns.barplot(x='internet', y='G3',data=data)

# %%
sns.barplot(x='freetime', y='G3',data=data)

# %%
sns.barplot(x='Dalc', y='G3',data=data)

# %%
sns.barplot(x='absences', y='G3',data=data)

# %% [markdown]
# ##**Data Cleaning**

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        4   0  11  11
# 1     GP   F   17       U     GT3       T  ...     1       3        2   9  11  11
# 2     GP   F   15       U     LE3       T  ...     3       3        6  12  13  12
# 3     GP   F   15       U     GT3       T  ...     1       5        0  14  14  14
# 4     GP   F   16       U     GT3       T  ...     2       5        0  11  13  13
#
# [5 rows x 32 columns]

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'guardian', 'traveltime', 'studytime', 'failures',
#        'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher',
#        'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc',
#        'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data = data[[ 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'guardian', 'traveltime', 'studytime', 'failures',
       'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher',
       'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc',
       'health', 'absences', 'G1', 'G2', 'G3']]

# %%
data.shape
# Out:
# (649, 31)

# %% [markdown]
# ##**Encode Categorical Data**

# %%
data.head()
# Out:
#   sex  age address famsize Pstatus  Medu  ...  Walc health absences  G1  G2  G3
# 0   F   18       U     GT3       A     4  ...     1      3        4   0  11  11
# 1   F   17       U     GT3       T     1  ...     1      3        2   9  11  11
# 2   F   15       U     LE3       T     1  ...     3      3        6  12  13  12
# 3   F   15       U     GT3       T     4  ...     1      5        0  14  14  14
# 4   F   16       U     GT3       T     3  ...     2      5        0  11  13  13
#
# [5 rows x 31 columns]

# %%
data = pd.get_dummies(data, drop_first=True)

# %%
data.head()
# Out:
#    age  Medu  Fedu  ...  higher_yes  internet_yes  romantic_yes
# 0   18     4     4  ...           1             0             0
# 1   17     1     1  ...           1             1             0
# 2   15     1     1  ...           1             1             0
# 3   15     4     2  ...           1             1             1
# 4   16     3     3  ...           1             0             0
#
# [5 rows x 38 columns]

# %%
data.shape
# Out:
# (649, 38)

# %% [markdown]
# ##**Splitting Data Set**

# %%
title = list(data.columns)
title
# Out:
# ['age',
#  'Medu',
#  'Fedu',
#  'traveltime',
#  'studytime',
#  'failures',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'G3',
#  'sex_M',
#  'address_U',
#  'famsize_LE3',
#  'Pstatus_T',
#  'Mjob_health',
#  'Mjob_other',
#  'Mjob_services',
#  'Mjob_teacher',
#  'Fjob_health',
#  'Fjob_other',
#  'Fjob_services',
#  'Fjob_teacher',
#  'guardian_mother',
#  'guardian_other',
#  'schoolsup_yes',
#  'famsup_yes',
#  'paid_yes',
#  'activities_yes',
#  'nursery_yes',
#  'higher_yes',
#  'internet_yes',
#  'romantic_yes']

# %%
title[15],title[37] = title[37],title[15]
title
# Out:
# ['age',
#  'Medu',
#  'Fedu',
#  'traveltime',
#  'studytime',
#  'failures',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'romantic_yes',
#  'sex_M',
#  'address_U',
#  'famsize_LE3',
#  'Pstatus_T',
#  'Mjob_health',
#  'Mjob_other',
#  'Mjob_services',
#  'Mjob_teacher',
#  'Fjob_health',
#  'Fjob_other',
#  'Fjob_services',
#  'Fjob_teacher',
#  'guardian_mother',
#  'guardian_other',
#  'schoolsup_yes',
#  'famsup_yes',
#  'paid_yes',
#  'activities_yes',
#  'nursery_yes',
#  'higher_yes',
#  'internet_yes',
#  'G3']

# %%
data = data[title]
data.head()
# Out:
#    age  Medu  Fedu  traveltime  ...  nursery_yes  higher_yes  internet_yes  G3
# 0   18     4     4           2  ...            1           1             0  11
# 1   17     1     1           1  ...            0           1             1  11
# 2   15     1     1           1  ...            1           1             1  12
# 3   15     4     2           1  ...            1           1             1  14
# 4   16     3     3           1  ...            1           1             0  13
#
# [5 rows x 38 columns]

# %%
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

# %% [markdown]
# #**Rigretion Model**

# %%
from xgboost import XGBRegressor
regressor = XGBRegressor()
regressor.fit(X_train, y_train)
# Out:
# [16:19:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
prediction = regressor.predict(X_test)
prediction
# Out:
# array([ 7.252046 , 14.740675 , 16.348066 , 10.512403 ,  9.300703 ,
#        12.559049 , 13.4061165, 17.624645 , 12.613836 , 11.274331 ,
#        10.468721 , 10.4151125, 13.013695 ,  8.599623 , 17.58403  ,
#        12.746558 , 12.992999 , 12.927804 , 10.576737 , 11.1081705,
#        12.383135 , 10.266388 , 17.514482 , 13.257725 , 12.930896 ,
#        -1.8990343, 12.903743 , 13.347491 , 11.357278 , 13.104184 ,
#        13.465981 , 16.172525 , 12.855287 , 15.736268 , 13.005392 ,
#         8.807292 ,  9.8899145, 11.233491 , 12.508459 , 11.00819  ,
#        15.691683 , 17.247988 , 11.37345  , 13.341023 , 12.91193  ,
#         9.523766 , 12.788843 , 10.089566 , 11.22532  ,  9.535247 ,
#         6.948268 , 15.037113 ,  9.479745 , 12.577418 ,  7.8909607,
#        10.611104 , 11.555517 , 11.398444 , 14.552195 , 14.396834 ,
#        13.453278 ,  7.1839705, 11.460882 ,  9.517215 , 13.089944 ],
#       dtype=float32)

# %%
sns.distplot(y_test-prediction)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(y_test,prediction)

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9126657195772334
